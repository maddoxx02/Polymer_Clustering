# %%
import Working_Elements.datareader as read_raw
import Clustering_Methods.Cluster_Hierarchy as HC
import Working_Elements.Final_Plotter as final
import Working_Elements.Initial_Plotter as initial
# Out:
# c:\Users\ashis\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data, original = read_raw.reader(r"C:\Users\ashis\Python Notebooks\Task 2\Data - 1 - TXT")

# data: stores individual sample in the format of 1 Dimensional numpy array (e.g. [0,1,2,3,1,2,2,3,1,3,.... N*N])
# original: stores the actual data from the sample in the dimension as is (e.g. [256,256] in csv,txt etc formats)

# %%
initial.plotter(original) 
# Plotting the original data

# %%
result = HC.hierarchy_Cluster(data,3)
# For Kmeans function, Data in 1 Dimensional format is given as input and the number of clusters required is given as a Parameter function

# %%
result
# Out:
# {0: [0, 1, 13], 1: [3, 4, 6, 7, 10, 12], 2: [2, 5, 8, 9, 11, 14]}

# %%
final.plotter(result,original)
# plotting the final results using the clustering result stored in "RESULTS" & "original" data from reading the actual data
