# %%
import sys
sys.path.insert(1, 'y:\\Gihub Repo Work\\stuff')

import Working_Elements.datareader as topg
import Clustering_Methods.Cluster_KMeans as KM
import Working_Elements.Final_Plotter as pp
import Working_Elements.Initial_Plotter as np
# Out:
# c:\Users\ashis\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data, original = topg.reader(r"C:\Users\ashis\Python Notebooks\Task 2\Data - 2 - TXT\Data 2_5-5")

# %%
np.plotter(original)
