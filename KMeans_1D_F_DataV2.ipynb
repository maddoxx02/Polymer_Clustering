# %%
import Working_Elements.datareader as read_raw
import Clustering_Methods.Cluster_KMeans as KM
import Working_Elements.Final_Plotter as final
import Working_Elements.Initial_Plotter_BIG as initial

import Working_Elements.Data_Processing.ONED_Fourier_Transform as F_1D

# other ways to import the libraries from the Repo
# #import Working_Elements.Data_Processing.ONE
# #from Working_Elements.Data_Processing import ONED_Fourier_Transform as dd
# Out:
# c:\Users\ashis\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\ashis\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\ashis\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data, original = read_raw.reader(r"C:\Users\ashis\Python Notebooks\Task 2\Data - 1 - TXT\Data_V2")

# %%
initial.plotter(original) 
# Plotting the original data

# %%
S = F_1D.Process(original)

# %%
KM.K_MEANS(S[0], 5) # COLUMNS
# Out:
# c:\Users\ashis\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# {0: [0, 2, 5, 6, 8, 36, 38, 41, 44, 63, 65, 66, 68, 69, 71],
#  1: [11,
#   12,
#   14,
#   17,
#   18,
#   20,
#   21,
#   23,
#   24,
#   26,
#   27,
#   29,
#   30,
#   32,
#   33,
#   43,
#   45,
#   47,
#   48,
#   50,
#   51,
#   53,
#   54,
#   57,
#   60,
#   72,
#   75,
#   78,
#   81,
#   84,
#   86,
#   87,
#   90,
#   92,
#   93,
#   96,
#   98,
#   99,
#   102,
#   104,
#   105,
#   107],
#  2: [9,
#   10,
#   13,
#   15,
#   16,
#   19,
#   22,
#   25,
#   28,
#   31,
#   34,
#   46,
#   49,
#   52,
#   55,
#   58,
#   61,
#   73,
#   76,
#   79,
#   82,
#   85,
#   88,
#   91,
#   94,
#   97,
#   100,
#   103,
#   106],
#  3: [1,
#   3,
#   4,
#   7,
#   35,
#   37,
#   39,
#   42,
#   56,
#   59,
#   62,
#   64,
#   67,
#   70,
#   74,
#   77,
#   80,
#   83,
#   89,
#   95,
#   101],
#  4: [40]}

# %%
print(KM.K_MEANS(S[1], 10)) # ROws
# Out:
# {0: [0, 2, 3, 5, 6, 8, 36, 39, 63], 1: [9, 12, 18, 21, 24, 27, 30, 32, 35, 45, 48, 51, 99, 102], 2: [50, 56, 62, 74, 80, 83, 89, 95, 98, 101], 3: [10, 13, 16, 25, 34, 55, 61, 79, 85, 106], 4: [40], 5: [1, 4, 7, 37, 64, 67, 70], 6: [19, 22, 28, 31, 43, 46, 49, 52, 58, 73, 76, 82, 88, 91, 94, 97, 100, 103], 7: [14, 15, 17, 26, 29, 42, 44, 47, 53, 54, 57, 59, 60, 72, 75, 77, 78, 81, 84, 86, 87, 90, 92, 93, 96, 104, 107], 8: [38, 41, 65, 66, 68, 69, 71], 9: [11, 20, 23, 33, 105]}
# c:\Users\ashis\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
final.plotter(KM.K_MEANS(S[1], 3), original)
#final.plotter(KM.K_MEANS(S[0], 3), original)
# Out:
# c:\Users\ashis\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# y:\Gihub Repo Work\stuff\Working_Elements\Final_Plotter.py:40: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()
